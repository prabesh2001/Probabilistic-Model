# %% [markdown]
# # 1. Required Libraries

# %%
import os
import re
import numpy as np
from collections import defaultdict
from math import log

# %% [markdown]
# # 2. text_preprocessing

# %%
# Preprocessing function
def preprocess(text):
    return re.findall(r'\b\w+\b', text.lower())

# %% [markdown]
# # 3. Loading documents

# %%
# Load documents
def load_documents(folder_path):
    docs = {}
    for filename in os.listdir(folder_path):
        if filename.endswith('.txt'):
            with open(os.path.join(folder_path, filename), 'r') as file:
                docs[filename] = preprocess(file.read())
    return docs

# %% [markdown]
# # 4. Loading queries

# %%
# Load queries
def load_queries(query_file_path):
    with open(query_file_path, 'r') as file:
        return [line.strip() for line in file.readlines()]

# %% [markdown]
# # 5. calculating TF and document frequency

# %%
# Compute term frequencies and document frequencies
def compute_statistics(docs):
    doc_count = len(docs)
    term_doc_freq = defaultdict(int)
    term_freq = defaultdict(lambda: defaultdict(int))

    for doc_id, words in docs.items():
        word_set = set(words)
        for word in words:
            term_freq[doc_id][word] += 1
        for word in word_set:
            term_doc_freq[word] += 1

    return term_freq, term_doc_freq, doc_count

# %% [markdown]
# # 6. calculating relevance Probability using BIM

# %%
# Compute relevance probabilities using BIM
def compute_relevance_prob(query, term_freq, term_doc_freq, doc_count):
    scores = {}
    for doc_id in term_freq:
        score = 1.0
        for term in query:
            tf = term_freq[doc_id].get(term, 0)
            df = term_doc_freq.get(term, 0)
            p_term_given_relevant = (tf + 1) / (sum(term_freq[doc_id].values()) + len(term_doc_freq))
            p_term_given_not_relevant = (df + 1) / (doc_count - df + len(term_doc_freq))
            score *= (p_term_given_relevant / p_term_given_not_relevant)
        scores[doc_id] = score
    return scores

# %% [markdown]
# # 7. Main Retrieval Function

# %%
# Main retrieval function
def retrieve_documents(folder_path, query_file_path):
    docs = load_documents(folder_path)
    queries = load_queries(query_file_path)

    term_freq, term_doc_freq, doc_count = compute_statistics(docs)

    # Open a file to write results
    with open('result_Prabesh.txt', 'w') as result_file:
        for query in queries:
            query_terms = preprocess(query)
            scores = compute_relevance_prob(query_terms, term_freq, term_doc_freq, doc_count)
            ranked_docs = sorted(scores.items(), key=lambda item: item[1], reverse=True)

            # Print to console
            print(f"Query: {query}")
            result_file.write(f"Query: {query}\n")

            # Print and write only the top 3 results with ranks
            for rank, (doc_id, score) in enumerate(ranked_docs[:3], start=1):
                print(f"Rank {rank}: Document:{doc_id}, Score: {score:.4f}")
                result_file.write(f"Rank {rank}: Document {doc_id}, Score: {score:.4f}\n")

            print()
            result_file.write("\n")

# Example usage
folder_path = '/content/drive/MyDrive/Information retrieval /Week-4_Lab,Probabilistic Model/datasets'
query_file_path = '/content/drive/MyDrive/Information retrieval /Week-4_Lab,Probabilistic Model/query_probabilistic_model.txt'
retrieve_documents(folder_path, query_file_path)
# Out:
# Query:
# Rank 1: Document document_1.txt, Score: 1.0000
# Rank 2: Document document_2.txt, Score: 1.0000
# Rank 3: Document document_3.txt, Score: 1.0000
#
# Query:
# Rank 1: Document document_1.txt, Score: 1.0000
# Rank 2: Document document_2.txt, Score: 1.0000
# Rank 3: Document document_3.txt, Score: 1.0000
#
# Query: Can
# Rank 1: Document document_11.txt, Score: 0.2029
# Rank 2: Document document_15.txt, Score: 0.2018
# Rank 3: Document document_10.txt, Score: 0.2002
#
# Query: deep
# Rank 1: Document document_1.txt, Score: 0.9014
# Rank 2: Document document_5.txt, Score: 0.3640
# Rank 3: Document document_13.txt, Score: 0.3610
#
# Query: learning
# Rank 1: Document document_1.txt, Score: 0.2946
# Rank 2: Document document_9.txt, Score: 0.2930
# Rank 3: Document document_6.txt, Score: 0.2438
#
# Query: and
# Rank 1: Document document_8.txt, Score: 0.2503
# Rank 2: Document document_2.txt, Score: 0.2483
# Rank 3: Document document_3.txt, Score: 0.2473
#
# Query: cloud
# Rank 1: Document document_19.txt, Score: 3.1561
# Rank 2: Document document_11.txt, Score: 0.4614
# Rank 3: Document document_15.txt, Score: 0.4589
#
# Query: computing
# Rank 1: Document document_19.txt, Score: 2.2544
# Rank 2: Document document_11.txt, Score: 0.4614
# Rank 3: Document document_15.txt, Score: 0.4589
#
# Query: improve
# Rank 1: Document document_1.txt, Score: 0.6027
# Rank 2: Document document_9.txt, Score: 0.5995
# Rank 3: Document document_11.txt, Score: 0.3072
#
# Query: medical
# Rank 1: Document document_5.txt, Score: 0.3640
# Rank 2: Document document_13.txt, Score: 0.3610
# Rank 3: Document document_1.txt, Score: 0.3605
#
# Query: image
# Rank 1: Document document_5.txt, Score: 0.4543
# Rank 2: Document document_1.txt, Score: 0.4500
# Rank 3: Document document_9.txt, Score: 0.4476
#
# Query: analysis
# Rank 1: Document document_20.txt, Score: 0.5646
# Rank 2: Document document_11.txt, Score: 0.2287
# Rank 3: Document document_5.txt, Score: 0.2265
#
# Query: making
# Rank 1: Document document_11.txt, Score: 0.3058
# Rank 2: Document document_5.txt, Score: 0.3029
# Rank 3: Document document_10.txt, Score: 0.3016
#
# Query: healthcare
# Rank 1: Document document_8.txt, Score: 0.9004
# Rank 2: Document document_12.txt, Score: 0.6076
# Rank 3: Document document_11.txt, Score: 0.3072
#
# Query: more
# Rank 1: Document document_5.txt, Score: 0.6085
# Rank 2: Document document_10.txt, Score: 0.6060
# Rank 3: Document document_11.txt, Score: 0.3072
#
# Query: efficient
# Rank 1: Document document_5.txt, Score: 0.9141
# Rank 2: Document document_11.txt, Score: 0.4614
# Rank 3: Document document_15.txt, Score: 0.4589
#
# Query: and
# Rank 1: Document document_8.txt, Score: 0.2503
# Rank 2: Document document_2.txt, Score: 0.2483
# Rank 3: Document document_3.txt, Score: 0.2473
#
# Query: accessible
# Rank 1: Document document_11.txt, Score: 0.9242
# Rank 2: Document document_15.txt, Score: 0.9192
# Rank 3: Document document_18.txt, Score: 0.9192
#
# Query:
# Rank 1: Document document_1.txt, Score: 1.0000
# Rank 2: Document document_2.txt, Score: 1.0000
# Rank 3: Document document_3.txt, Score: 1.0000
#
# Query:
# Rank 1: Document document_1.txt, Score: 1.0000
# Rank 2: Document document_2.txt, Score: 1.0000
# Rank 3: Document document_3.txt, Score: 1.0000
#
# Query:
# Rank 1: Document document_1.txt, Score: 1.0000
# Rank 2: Document document_2.txt, Score: 1.0000
# Rank 3: Document document_3.txt, Score: 1.0000
#
# Query:
# Rank 1: Document document_1.txt, Score: 1.0000
# Rank 2: Document document_2.txt, Score: 1.0000
# Rank 3: Document document_3.txt, Score: 1.0000
#
# Query: will
# Rank 1: Document document_8.txt, Score: 0.9017
# Rank 2: Document document_11.txt, Score: 0.4614
# Rank 3: Document document_15.txt, Score: 0.4589
#
# Query: AI
# Rank 1: Document document_10.txt, Score: 1.2688
# Rank 2: Document document_8.txt, Score: 1.0773
# Rank 3: Document document_3.txt, Score: 1.0644
#
# Query: and
# Rank 1: Document document_8.txt, Score: 0.2503
# Rank 2: Document document_2.txt, Score: 0.2483
# Rank 3: Document document_3.txt, Score: 0.2473
#
# Query: automation
# Rank 1: Document document_8.txt, Score: 1.3526
# Rank 2: Document document_11.txt, Score: 0.4614
# Rank 3: Document document_15.txt, Score: 0.4589
#
# Query: transform
# Rank 1: Document document_11.txt, Score: 0.9242
# Rank 2: Document document_15.txt, Score: 0.9192
# Rank 3: Document document_18.txt, Score: 0.9192
#
# Query: the
# Rank 1: Document document_17.txt, Score: 0.3456
# Rank 2: Document document_14.txt, Score: 0.2974
# Rank 3: Document document_3.txt, Score: 0.2899
#
# Query: future
# Rank 1: Document document_8.txt, Score: 0.6743
# Rank 2: Document document_12.txt, Score: 0.4550
# Rank 3: Document document_20.txt, Score: 0.4544
#
# Query: of
# Rank 1: Document document_3.txt, Score: 0.2899
# Rank 2: Document document_14.txt, Score: 0.2478
# Rank 3: Document document_6.txt, Score: 0.2438
#
# Query: industries
# Rank 1: Document document_8.txt, Score: 0.9017
# Rank 2: Document document_11.txt, Score: 0.4614
# Rank 3: Document document_15.txt, Score: 0.4589
#
# Query: and
# Rank 1: Document document_8.txt, Score: 0.2503
# Rank 2: Document document_2.txt, Score: 0.2483
# Rank 3: Document document_3.txt, Score: 0.2473
#
# Query: job
# Rank 1: Document document_11.txt, Score: 0.9242
# Rank 2: Document document_15.txt, Score: 0.9192
# Rank 3: Document document_18.txt, Score: 0.9192
#
# Query: markets
# Rank 1: Document document_11.txt, Score: 0.9242
# Rank 2: Document document_15.txt, Score: 0.9192
# Rank 3: Document document_18.txt, Score: 0.9192
#
# Query: ensuring
# Rank 1: Document document_10.txt, Score: 0.9090
# Rank 2: Document document_7.txt, Score: 0.6052
# Rank 3: Document document_11.txt, Score: 0.3072
#
# Query: a
# Rank 1: Document document_16.txt, Score: 0.4422
# Rank 2: Document document_9.txt, Score: 0.3790
# Rank 3: Document document_17.txt, Score: 0.3193
#
# Query: thriving
# Rank 1: Document document_11.txt, Score: 0.9242
# Rank 2: Document document_15.txt, Score: 0.9192
# Rank 3: Document document_18.txt, Score: 0.9192
#
# Query: economy
# Rank 1: Document document_11.txt, Score: 0.9242
# Rank 2: Document document_15.txt, Score: 0.9192
# Rank 3: Document document_18.txt, Score: 0.9192
#
# Query: and
# Rank 1: Document document_8.txt, Score: 0.2503
# Rank 2: Document document_2.txt, Score: 0.2483
# Rank 3: Document document_3.txt, Score: 0.2473
#
# Query: new
# Rank 1: Document document_13.txt, Score: 0.3857
# Rank 2: Document document_14.txt, Score: 0.2592
# Rank 3: Document document_12.txt, Score: 0.2589
#
# Query: opportunities
# Rank 1: Document document_8.txt, Score: 0.9017
# Rank 2: Document document_11.txt, Score: 0.4614
# Rank 3: Document document_15.txt, Score: 0.4589
#
# Query: for
# Rank 1: Document document_12.txt, Score: 0.2984
# Rank 2: Document document_15.txt, Score: 0.1800
# Rank 3: Document document_18.txt, Score: 0.1800
#
# Query: education
# Rank 1: Document document_8.txt, Score: 0.9017
# Rank 2: Document document_11.txt, Score: 0.4614
# Rank 3: Document document_15.txt, Score: 0.4589
#
# Query: and
# Rank 1: Document document_8.txt, Score: 0.2503
# Rank 2: Document document_2.txt, Score: 0.2483
# Rank 3: Document document_3.txt, Score: 0.2473
#
# Query: skilled
# Rank 1: Document document_11.txt, Score: 0.9242
# Rank 2: Document document_15.txt, Score: 0.9192
# Rank 3: Document document_18.txt, Score: 0.9192
#
# Query: labor
# Rank 1: Document document_11.txt, Score: 0.9242
# Rank 2: Document document_15.txt, Score: 0.9192
# Rank 3: Document document_18.txt, Score: 0.9192
